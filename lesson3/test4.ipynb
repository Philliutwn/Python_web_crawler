# %%
import json
class Site:
    def __init__(self, sitename, county, aqi, pollutant, status, pm2_5, pm2_5_avg, latitude, longitude, datacreationdate):
        self.sitename = sitename
        self.county = county
        self.aqi = aqi
        self.pollutant = pollutant
        self.status = status
        self.pm2_5 = pm2_5
        self.pm2_5_avg = pm2_5_avg
        self.latitude = latitude
        self.longitude = longitude
        self.datacreationdate = datacreationdate

    def __repr__(self):
        return f'''
        sitename = {self.sitename}
        county = {self.county}
        aqi = {self.aqi}
        pollutant = {self.pollutant}
        status = {self.status}
        pm2_5 = {self.pm2_5}
        pm2_5_avg = {self.pm2_5_avg}
        latitude = {self.latitude}
        longitude = {self.longitude}
        datacreationdate = {self.datacreationdate}\n'''

with open('aqx_p_488.json','r',encoding='utf-8') as file:
    data = json.load(file)

allData = []
for i in data['records']:
    s1 = Site (
        sitename = i['sitename'],
        county = i['county'],
        aqi = i['aqi'],
        pollutant = i['pollutant'],
        status = i['status'],
        pm2_5 = i['pm2.5'],
        pm2_5_avg = i['pm2.5_avg'],
        latitude = i['latitude'],
        longitude = i['longitude'],
        datacreationdate = i['datacreationdate']
    )
    allData.append(s1)    

print(len(allData))

for s1 in allData:
    print('站點名稱：', s1.sitename)
    print('縣市：', s1.county)
    print('空氣品質指數：', si.aqi)
    print('主要污染物：', s1.pollutant)
    print('狀態：', s1.status)
    print('PM2.5：', s1.pm2_5)
    print('PM2.5_AVG：', s1.pm2_5_avg)
    print('經度：', s1.latitude)
    print('緯度：', s1.longitude)
    print('資料創建日期：', s1.datacreationdate)
    print('============================')
# Out:
# 1000
# 站點名稱： 屏東(枋山)
# 縣市： 屏東縣
# 空氣品質指數： 52
# 主要污染物： 懸浮微粒
# 狀態： 普通
# PM2.5： 10
# PM2.5_AVG： 9.2
# 經度： 22.260899
# 緯度： 120.651472
# 資料創建日期： 2025-07-15 10:00
# ...
# 站點名稱： 臺南（南化）
# 縣市： 臺南市
# 空氣品質指數： 52
# 主要污染物：
# 狀態： 良好
# PM2.5： 7
# PM2.5_AVG： 6.2
# 經度： 23.04562013
# 緯度： 120.44583156
# 資料創建日期： 2025-07-15 10:00
# ...
# 站點名稱： 新北(樹林)
# 縣市： 新北市
# 空氣品質指數： 52
# 主要污染物：
# 狀態： 良好
# PM2.5： 7
# PM2.5_AVG： 9.5
# 經度： 24.94902778
# 緯度： 121.38352778
# 資料創建日期： 2025-07-15 10:00
# ...
# 站點名稱： 台中市（和平區消防隊）
# 縣市： 臺中市
# 空氣品質指數： 52
# 主要污染物：
# 狀態： 良好
# PM2.5： 5
# PM2.5_AVG： 5.4
# 經度： 24.174592
# 緯度： 120.883858
# 資料創建日期： 2025-07-15 10:00
# ...
# 站點名稱： 屏東（琉球）
# 縣市： 屏東縣
# 空氣品質指數： 52
# 主要污染物：
# 狀態： 良好
# PM2.5： 9
# PM2.5_AVG： 11.4
# 經度： 22.35222
# 緯度： 120.37722
# 資料創建日期： 2025-07-15 10:00
# ...
# 站點名稱： 南投（鹿谷）
# 縣市： 南投縣
# 空氣品質指數： 52
# 主要污染物：
# 狀態： 良好
# PM2.5： 7
# PM2.5_AVG： 6.4
# 經度： 23.71867609
# 緯度： 120.7944772
# 資料創建日期： 2025-07-15 10:00
# ...
# 站點名稱： 高雄（湖內）
# 縣市： 高雄市
# 空氣品質指數： 52
# 主要污染物：
# 狀態： 良好
# PM2.5： 8
# PM2.5_AVG： 8.1
# 經度： 22.87985556
# ...

# %%
print(type(s1))
print(type(Site))
print(allData)

a = list[1,2,3,4,5]
print(a)
# Out:
# <class '__main__.Site'>
# <class 'type'>
# [
#         sitename = 屏東(枋山)
#         county = 屏東縣
#         aqi = 55
#         pollutant = 懸浮微粒
#         status = 普通
#         pm2_5 = 10
#         pm2_5_avg = 9.2
#         latitude = 22.260899
#         longitude = 120.651472
#         datacreationdate = 2025-07-15 10:00
# ,
#         sitename = 臺南（南化）
#         county = 臺南市
#         aqi = 25
#         pollutant =
#         status = 良好
#         pm2_5 = 7
#         pm2_5_avg = 6.2
#         latitude = 23.04562013
#         longitude = 120.44583156
#         datacreationdate = 2025-07-15 10:00
# ,
#         sitename = 新北(樹林)
#         county = 新北市
#         aqi = 47
#         pollutant =
#         status = 良好
#         pm2_5 = 7
#         pm2_5_avg = 9.5
#         latitude = 24.94902778
#         longitude = 121.38352778
#         datacreationdate = 2025-07-15 10:00
# ,
#         sitename = 台中市（和平區消防隊）
#         county = 臺中市
#         aqi = 32
#         pollutant =
# ...
