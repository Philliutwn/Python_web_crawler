# %%
import json
from pprint import pprint

with open('aqx_p_488.json','r', encoding='utf-8') as f:
    data = json.load(f)          # data 是一個 list data[ ], data list 內儲存的是 dictionary { }

for i in data['records']:
    print(i['sitename'])
    print(i['county'])
    print(i['aqi'])
    print(i['pollutant'])
    print(i['status'])
    print('--------------------------')
# Out:
# 屏東(枋山)
# 屏東縣
# 55
# 懸浮微粒
# 普通
# --------------------------
# 臺南（南化）
# 臺南市
# 25
#
# 良好
# --------------------------
# 新北(樹林)
# 新北市
# 47
#
# 良好
# --------------------------
# 台中市（和平區消防隊）
# 臺中市
# 32
#
# 良好
# --------------------------
# 屏東（琉球）
# 屏東縣
# 46
#
# 良好
# --------------------------
# 南投（鹿谷）
# 南投縣
# 30
#
# 良好
# --------------------------
# 高雄（湖內）
# 高雄市
# 38
#
# 良好
# --------------------------
# 宜蘭（三星）
# 宜蘭縣
# 47
#
# 良好
# --------------------------
# 員林
# 彰化縣
# 53
# 細懸浮微粒
# 普通
# --------------------------
# 大城
# 彰化縣
# 28
#
# 良好
# --------------------------
# 富貴角
# 新北市
# 46
#
# 良好
# --------------------------
# 麥寮
# 雲林縣
# 23
#
# 良好
# --------------------------
# 關山
# 臺東縣
# 48
#
# 良好
# --------------------------
# 馬公
# 澎湖縣
# 42
#
# 良好
# --------------------------
# 金門
# 金門縣
# 59
# 細懸浮微粒
# 普通
# --------------------------
# 馬祖
# 連江縣
# 97
# 細懸浮微粒
# 普通
# --------------------------
# 埔里
# 南投縣
# 37
#
# 良好
# --------------------------
# 復興
# 高雄市
# 35
#
# 良好
# --------------------------
# ...

# %%
#a : list = []
a = [{'sitename' : 'Taipei', 'aqi' : 5.5, 'status' : 'normal'}, {'sitename' : 'Keelung', 'aqi' : 3.5, 'status' : 'bad'}, {'sitename' : 'Taichung', 'aqi' : 6, 'status' : 'good'}]
print(a)

for i in a:                        # i 讀出來的是list內的dictionary
    #print(i['sitename'])
    #print(f'{i}: ')
    #print(f'{i["sitename"]}')
    for j in i:                    # j 讀出來的是 i dictionary 的 key
        print(j,':', i[j])         # i[j] 讀出來的是 i 的 value
# Out:
# [{'sitename': 'Taipei', 'aqi': 5.5, 'status': 'normal'}, {'sitename': 'Keelung', 'aqi': 3.5, 'status': 'bad'}, {'sitename': 'Taichung', 'aqi': 6, 'status': 'good'}]
# sitename : Taipei
# aqi : 5.5
# status : normal
# sitename : Keelung
# aqi : 3.5
# status : bad
# sitename : Taichung
# aqi : 6
# status : good

# %%
dic10 = {'Taipei':'101','Paris':'Tour Eiffel','London':'Big Ben'} 
#print(dic10) 
for i in dic10:
    print(f'{i} : {dic10[i]}')
# Out:
# Taipei : 101
# Paris : Tour Eiffel
# London : Big Ben
