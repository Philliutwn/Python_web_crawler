# %%
import json
from pprint import pprint

with open('aqx_p_488.json','r', encoding='utf-8') as f:
    data = json.load(f)
pprint(data)
# Out:
#   Cell In[1], line 4
#     with open('aqx_p_488.json','r', encoding='utf-8') as f
#                                                           ^
# SyntaxError: expected ':'
