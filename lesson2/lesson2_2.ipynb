# %% [markdown]
# ### Python Basics

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
name = "Alice"
age = 25
height = 1.65
is_student = True

print(name)
print(age)
print(height)
print(is_student)
# Out:
# Alice
# 25
# 1.65
# True

# %%
a = 10
b = 5
sum_result = a + b
print("Sum:", sum_result)
# Out:
# Sum: 15

# %%
print("Hello", "world",sep="-", end="!")
# Out:
# Hello-world!

# %%
result = a**b
print("Power:", result)
# Out:
# Power: 100000
